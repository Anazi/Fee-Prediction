# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
import graphlab
# %matplotlib inline

# %%
data = pandas.read_csv("Case_data_set.csv")

# %%
sf = graphlab.SFrame('Case_data_set.csv')
# Out:
# Finished parsing file /Users/fahad.bari/Documents/Study/ML Basic/ML files/Fee Prediction/Case_data_set.csv
# Parsing completed. Parsed 40 lines in 0.033266 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,int,int,int,int,int,int,int,int,int,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/fahad.bari/Documents/Study/ML Basic/ML files/Fee Prediction/Case_data_set.csv
# Parsing completed. Parsed 40 lines in 0.012067 secs.

# %%
import pandas as pd

# %%
data = pd.read_csv("Case_data_set.csv")

# %%
data.head(40)
# Out:
#     Number_of_Employees  Number_of_Policies  Number_of_Locations  \
# 0                 388.0                11.0                 37.0
# 1                  20.0                 6.0                  1.0
# 2                   1.0                 2.0                  1.0
# 3                 124.0                 9.0                 20.0
# 4                3331.0                45.0                 55.0
# 5                  25.0                 8.0                  1.0
# 6                  92.0                12.0                  6.0
# 7                  46.0                 9.0                  1.0
# 8                  14.0                 7.0                  1.0
# 9                  38.0                 8.0                  3.0
# 10                 25.0                 6.0                  1.0
# 11                170.0                 9.0                  1.0
# 12                589.0                13.0                 10.0
# ...

# %%
data.columns = ['Number_of_Employees','Number_of_Policies','Number_of_Locations','Number_of_States_in_Which_Employees_Regularly_Work','Number_of_Annual_Contacts_with_Client','Number_of_Renewal_Dates','Number_of_Certificates_of_Insurance_Issued_Annually','Number_of_Contracts_Reviewed_Annually','Number_of_Claims_Over_the_Past_Three_Years','Number_of_Owned_Vehicles','Current_Annual_Fee']

# %%
data.describe()
# Out:
#        Number_of_Employees  Number_of_Policies  Number_of_Locations  \
# count            40.000000            40.00000            40.000000
# mean            185.050000             9.12500             6.825000
# std             527.232151             7.32466            12.006168
# min               0.000000             2.00000             1.000000
# 25%              17.250000             6.00000             1.000000
# 50%              45.500000             8.00000             1.000000
# 75%             135.500000             9.50000             6.000000
# max            3331.000000            45.00000            55.000000
#
#        Number_of_States_in_Which_Employees_Regularly_Work  \
# count                                          40.000000
# mean                                            6.300000
# std                                            10.725479
# min                                             0.000000
# 25%                                             1.000000
# ...

# %%
data['Number_of_Renewal_Dates'].value_counts().plot(kind='bar')
plt.title('Number of Renewal Dates')
plt.xlabel('Renewal Dates')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
data['Number_of_States_in_Which_Employees_Regularly_Work'].value_counts().plot(kind='bar')
plt.title('place of work')
plt.xlabel('Policies')
plt.ylabel('max')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
data['Number_of_Certificates_of_Insurance_Issued_Annually'].value_counts().plot(kind='bar')
plt.title('Number of Certificates of Insurance Issued Annually')
plt.xlabel('Certificates of Insurance-Annually')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
plt.scatter(data.Current_Annual_Fee,data.Number_of_Renewal_Dates)
plt.title("Annual fee vs contact with Client")

# %%
sns.set(style='whitegrid', context = 'notebook')
cols = ['Number_of_Employees','Number_of_Renewal_Dates','Number_of_Locations','Number_of_States_in_Which_Employees_Regularly_Work','Number_of_Annual_Contacts_with_Client','Current_Annual_Fee']

# %%
sns.pairplot(data[cols], size =5)
plt.show()

# %%
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale = 1.5)
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size':15},yticklabels=cols,xticklabels=cols)
plt.show()

# %% [markdown]
# Reference:
# There is some kind of co relation here and we see that irrespective of the data types(factors).
# We notice that, 'Number_of_Annual_Contacts_with_Client' and 'Number_of_Locations' are 2 parameters which as per Heatmap are very close to 1. And hence, Will be considered as factors.
# But looking at relativity, we come to the conclusion that 'Number_of_Annual_Contacts_with_Client', can be used as Primary Factor.

# %% [markdown]
# X = data[('Number_of_Locations')].values
# y = data[('Current_Annual_Fee')].values

# %% [markdown]
# print(y)
# print(X.shape)
# print(y.shape)

# %%
train1 = data.drop(['Number_of_Employees', 'Current_Annual_Fee'],axis=1)

# %%
train1.head(40)
# Out:
#     Number_of_Policies  Number_of_Locations  \
# 0                 11.0                 37.0
# 1                  6.0                  1.0
# 2                  2.0                  1.0
# 3                  9.0                 20.0
# 4                 45.0                 55.0
# 5                  8.0                  1.0
# 6                 12.0                  6.0
# 7                  9.0                  1.0
# 8                  7.0                  1.0
# 9                  8.0                  3.0
# 10                 6.0                  1.0
# 11                 9.0                  1.0
# 12                13.0                 10.0
# 13                 6.0                  1.0
# 14                 6.0                  1.0
# 15                 9.0                  1.0
# 16                12.0                 16.0
# 17                 4.0                  1.0
# 18                 8.0                  3.0
# 19                 4.0                  1.0
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data['Current_Annual_Fee']
train1 = data.drop(['Number_of_Certificates_of_Insurance_Issued_Annually','Current_Annual_Fee'],axis=1)

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([  -17.11848687,  2671.65140398,   783.59608999, -1267.76791326,
#          100.65505179, -2663.65358008,  1366.00737073,   593.56212236,
#          319.28570495])

# %%
a = reg.predict(x_test)

# %%
a[1]
# Out:
# 30322.469971064977

# %%
y_test
# Out:
# 27    11200.0
# 9     18200.0
# 14     3000.0
# 0     61000.0
# Name: Current_Annual_Fee, dtype: float64

# %%
reg.score(x_test,y_test)
# Out:
# 0.82903110343195585

# %% [markdown]
# t_sc = np.zeros((params['n_estimators']),dtype=np.float64)

# %%
y_pred = reg.predict(x_test)

# %% [markdown]
# for i,y_pred in enumerate(clf.staged_predict(x_test)):
#     t_sc[i]=clf.loss_(y_test,y_pred)

# %% [markdown]
# testsc = np.arange((params['n_estimators']))+1

# %% [markdown]
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.plot(testsc,clf.train_score_,'b-',label= 'Set dev train')
# plt.plot(testsc,t_sc,'r-',label = 'set dev test')
